# %%
#RNN Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

X_train_rnn = np.random.random((1000, 10, 1))
X_test_rnn = np.random.random((100, 10, 1))
y_train_rnn = np.random.randint(0, 2, (1000,))

rnn_model = Sequential([
    LSTM(64, input_shape=(X_train_rnn.shape[1], X_train_rnn.shape[2])),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

rnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
rnn_model.fit(X_train_rnn, y_train_rnn, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 4s 93ms/step - loss: 0.6957 - accuracy: 0.4775 - val_loss: 0.6935 - val_accuracy: 0.4650
# Epoch 2/10
# 25/25 [==============================] - 0s 16ms/step - loss: 0.6937 - accuracy: 0.4863 - val_loss: 0.6915 - val_accuracy: 0.5450
# Epoch 3/10
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6943 - accuracy: 0.4825 - val_loss: 0.6931 - val_accuracy: 0.5150
# Epoch 4/10
# 25/25 [==============================] - 0s 16ms/step - loss: 0.6934 - accuracy: 0.5063 - val_loss: 0.6926 - val_accuracy: 0.5350
# Epoch 5/10
# 25/25 [==============================] - 0s 15ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6938 - val_accuracy: 0.4550
# Epoch 6/10
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6929 - accuracy: 0.5263 - val_loss: 0.6933 - val_accuracy: 0.4650
# Epoch 7/10
# ...

# %%
#CNN Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

X_train_cnn = np.random.random((1000, 28, 28, 1))
X_test_cnn = np.random.random((100, 28, 28, 1))
y_train_cnn = np.random.randint(0, 10, (1000,))

cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_model.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 2s 32ms/step - loss: 2.3441 - accuracy: 0.1025 - val_loss: 2.3096 - val_accuracy: 0.0900
# Epoch 2/10
# 25/25 [==============================] - 1s 20ms/step - loss: 2.2945 - accuracy: 0.1075 - val_loss: 2.3115 - val_accuracy: 0.1350
# Epoch 3/10
# 25/25 [==============================] - 1s 21ms/step - loss: 2.2538 - accuracy: 0.1425 - val_loss: 2.3214 - val_accuracy: 0.1050
# Epoch 4/10
# 25/25 [==============================] - 1s 20ms/step - loss: 2.2178 - accuracy: 0.2225 - val_loss: 2.3145 - val_accuracy: 0.1000
# Epoch 5/10
# 25/25 [==============================] - 1s 21ms/step - loss: 2.1422 - accuracy: 0.3000 - val_loss: 2.3195 - val_accuracy: 0.1350
# Epoch 6/10
# 25/25 [==============================] - 1s 20ms/step - loss: 2.0370 - accuracy: 0.3887 - val_loss: 2.4285 - val_accuracy: 0.1000
# Epoch 7/10
# ...

# %%
#ANN Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

X_train_ann = np.random.random((1000, 10))
X_test_ann = np.random.random((100, 10))
y_train_ann = np.random.randint(0, 2, (1000,))

ann_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_ann.shape[1],)),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
ann_model.fit(X_train_ann, y_train_ann, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 1s 11ms/step - loss: 0.6944 - accuracy: 0.5075 - val_loss: 0.6888 - val_accuracy: 0.5500
# Epoch 2/10
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6901 - accuracy: 0.5612 - val_loss: 0.6887 - val_accuracy: 0.5300
# Epoch 3/10
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6928 - accuracy: 0.5175 - val_loss: 0.6882 - val_accuracy: 0.5550
# Epoch 4/10
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6911 - accuracy: 0.5250 - val_loss: 0.6881 - val_accuracy: 0.5450
# Epoch 5/10
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6921 - accuracy: 0.5188 - val_loss: 0.6880 - val_accuracy: 0.5500
# Epoch 6/10
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6887 - accuracy: 0.5412 - val_loss: 0.6880 - val_accuracy: 0.5550
# Epoch 7/10
# ...
